# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("agentica-org/DeepScaleR-Preview-Dataset")

# %%
x=1

# %%
ds['train']['problem'][0]
# Out:
# 'The operation $\\otimes$ is defined for all nonzero numbers by $a \\otimes b = \\frac{a^{2}}{b}$. Determine $[(1 \\otimes 2) \\otimes 3] - [1 \\otimes (2 \\otimes 3)]$.'

# %%
ds['train']['answer'][0]
# Out:
# '-\\frac{2}{3}'

# %%
ds = load_dataset("math-dataset/DeepScaleR-Preview-Dataset")
# Out:
# README.md:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# deepscaler.json:   0%|          | 0.00/21.5M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/40315 [00:00<?, ? examples/s]

# %%
ds['train']['answer'][3]
# Out:
# '\\frac{\\sqrt{2}}{2}'
